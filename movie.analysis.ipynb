# %% [markdown]
# Importing all necessary files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# reading Data from file and making the dataframe

# %%
df=pd.read_csv('movie_data.csv')
df.head(10)
# Out:
#                                            Title Rating          Genre  \
# 0                                       Twisters    72%         Action
# 1                                Despicable Me 4    72%  Kids & Family
# 2          Paris Olympics on NBC at AMC Theatres    72%         Sports
# 3  NBC's Paris Olympics Opening Ceremony in IMAX    72%         Sports
# 4                             Fly Me to the Moon    72%        Romance
# 5                                       MaXXXine    72%         Horror
# 6                                       Longlegs    72%         Horror
# 7                                          Touch    72%        Romance
# 8                         A Quiet Place: Day One    72%         Horror
# 9                                   Inside Out 2    72%  Kids & Family
#
#              Release Date Reviews Count Rating Code Duration
# 0  In Theaters Fri Jul 19    38 Reviews       PG-13    2h 2m
# 1             Now Playing   145 Reviews          PG   1h 35m
# 2  In Theaters Fri Jul 26       Reviews       PG-13    4h 0m
# 3  In Theaters Fri Jul 26       Reviews           R   2h 12m
# 4             Now Playing   163 Reviews           R   1h 41m
# 5             Now Playing   232 Reviews           R   1h 41m
# 6             Now Playing   166 Reviews       PG-13    2h 1m
# 7             Now Playing    38 Reviews          PG   1h 40m
# 8             Now Playing   249 Reviews           R   1h 36m
# 9             Now Playing   296 Reviews       PG-13   2h 13m
